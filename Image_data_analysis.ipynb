# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_dir = "/content/drive/MyDrive/Final_Project/images"

# %%
import tensorflow as tf
import os

# %%
#Count how many images we have in each folder, folders are sorted by sports disciplines

image_dict = {}

for folder in os.listdir("/content/drive/MyDrive/Final_Project/images"):
  #print(folder)
  temp = []
  
  for file in os.listdir("/content/drive/MyDrive/Final_Project/images/" + folder):
    #print(file)
    temp.append(file)
  print(folder+" has "+ str(len(temp)))
  x = {folder: str(len(temp))}
  image_dict.update(x)


print(image_dict)
# Out:
# Table tennis has 500
# Roller hockey has 707
# Parachuting has 622
# Rugby union has 726
# Nordic skiing has 635
# Rallycross has 481
# no sport has 1000
# Wakeboarding has 691
# Olympic weightlifting has 818
# Sprint car racing has 530
# Flag football has 606
# Airsoft has 530
# Motocross has 787
# Muay Thai has 662
# Karate has 611
# Beach volleyball has 734
# Cycle polo has 572
# {'Table tennis': '500', 'Roller hockey': '707', 'Parachuting': '622', 'Rugby union': '726', 'Nordic skiing': '635', 'Rallycross': '481', 'no sport': '1000', 'Wakeboarding': '691', 'Olympic weightlifting': '818', 'Sprint car racing': '530', 'Flag football': '606', 'Airsoft': '530', 'Motocross': '787', 'Muay Thai': '662', 'Karate': '611', 'Beach volleyball': '734', 'Cycle polo': '572'}

# %%
#Plot pie chart showing list of sports and ratio of each sports images in data

import matplotlib.pyplot as plt

# %%
# Get the Keys and store them in a list
labels = list(image_dict.keys())

# Get the Values and store them in a list
values = list(image_dict.values())

# %%
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, radius = 2)

plt.show()
